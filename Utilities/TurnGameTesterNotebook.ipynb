# %% [markdown]
# # IMPORT

# %%
# IMPORT FOR BASIC UTILITIES

import sys
import io
import gc
import os
import pickle
from tqdm import tqdm
from matplotlib import pyplot as plt
import seaborn as sns
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import numpy as np
import gym
import itertools
import pandas as pd

# %%
# GPU QUALITY CHECK

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Aug 24 10:01:36 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# MOUNT DRIVE

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# CLONE REPOSITORY

token = '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'
repo_url = 'https://' + token + '@github.com/Menta99/Advanced_Deep_Learning_Models_and_Methods-Menta-Nisti.git'
# !git clone $repo_url
# Out:
# Cloning into 'Advanced_Deep_Learning_Models_and_Methods-Menta-Nisti'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 401 (delta 9), reused 16 (delta 6), pack-reused 375
# Receiving objects: 100% (401/401), 693.76 KiB | 14.45 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
# REPOSITORY IMPORTS

sys.path.append('/content/Advanced_Deep_Learning_Models_and_Methods-Menta-Nisti/')
sys.path.append('/content/Advanced_Deep_Learning_Models_and_Methods-Menta-Nisti/Utilities/')

from Agents.DDDQN.DDDQNAgent import DDDQNAgent
from Agents.SAC.SACAgent import SACAgent
from Utilities.TicTacToe import TicTacToeEnv
from Utilities.ConnectFour import ConnectFourEnv
from Utilities.Santorini import SantoriniEnv
from Utilities.Wrappers import OpponentWrapper
from Utilities.TrainWizard import TurnGameTrainWizard

# %% [markdown]
# # TEST SETUP

# %%
# CONFIGURATION UTILITIES

def get_turn(config_turn):
    if config_turn == 'First':
        return True
    elif config_turn == 'Second':
        return False
    elif config_turn == 'Random':
        return None
    else:
        raise ValueError('Turn provided does not exist!')


def get_env(config_environment, config_representation, config_turn, config_opponent):
    if config_environment == 'TicTacToe':
        return OpponentWrapper(TicTacToeEnv(config_representation, config_turn), config_opponent)
    elif config_environment == 'ConnectFour':
        return OpponentWrapper(ConnectFourEnv(config_representation, config_turn), config_opponent)
    elif config_environment == 'Santorini':
        return OpponentWrapper(SantoriniEnv(config_representation, config_turn, True, False, 0, 0), config_opponent)
    else:
        raise ValueError('Game provided does not exist!')


def get_network_dicts(config_algorithm, config_representation, config_environment):
    if config_algorithm == 'DDDQN':
        if config_representation == 'Tabular':
            network_dict_base = {0:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 64,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                                 1:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 32,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                                 2:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 16,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }}}
            network_dict_advantage = {3:
                                          {'name': 'Flatten',
                                           'params': {}
                                           },
                                      4:
                                          {'name': 'Dense',
                                           'params': {
                                               'units': 512,
                                               'activation': 'relu',
                                               'kernel_initializer': tf.keras.initializers.HeNormal()
                                           }},
                                      5:
                                          {'name': 'Dense',
                                           'params': {
                                               'units': config_environment.action_space.n,
                                               'activation': None
                                           }}}
            network_dict_value = {6:
                                      {'name': 'Flatten',
                                       'params': {}
                                       },
                                  7:
                                      {'name': 'Dense',
                                       'params': {
                                           'units': 512,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                                  8:
                                      {'name': 'Dense',
                                       'params': {
                                           'units': 1,
                                           'activation': None
                                       }}}
            return [network_dict_base, network_dict_advantage, network_dict_value]
        elif config_representation == 'Graphic':
            network_dict_base = {0:
                                     {'name': 'Conv2D',
                                      'params': {
                                          'filters': 32,
                                          'kernel_size': (8, 8),
                                          'strides': (4, 4),
                                          'activation': 'relu',
                                          'kernel_initializer': tf.keras.initializers.HeNormal()
                                      }},
                                 1:
                                     {'name': 'Conv2D',
                                      'params': {
                                          'filters': 64,
                                          'kernel_size': (4, 4),
                                          'strides': (2, 2),
                                          'activation': 'relu',
                                          'kernel_initializer': tf.keras.initializers.HeNormal()
                                      }},
                                 2:
                                     {'name': 'Conv2D',
                                      'params': {
                                          'filters': 64,
                                          'kernel_size': (3, 3),
                                          'strides': (1, 1),
                                          'activation': 'relu',
                                          'kernel_initializer': tf.keras.initializers.HeNormal()
                                      }}}
            network_dict_advantage = {3:
                                          {'name': 'Flatten',
                                           'params': {}
                                           },
                                      4:
                                          {'name': 'Dense',
                                           'params': {
                                               'units': 512,
                                               'activation': 'relu',
                                               'kernel_initializer': tf.keras.initializers.HeNormal()
                                           }},
                                      5:
                                          {'name': 'Dense',
                                           'params': {
                                               'units': config_environment.action_space.n,
                                               'activation': None
                                           }}}
            network_dict_value = {6:
                                      {'name': 'Flatten',
                                       'params': {}
                                       },
                                  7:
                                      {'name': 'Dense',
                                       'params': {
                                           'units': 512,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                                  8:
                                      {'name': 'Dense',
                                       'params': {
                                           'units': 1,
                                           'activation': None
                                       }}}
            return [network_dict_base, network_dict_advantage, network_dict_value]
        else:
            raise ValueError('Representation provided does not exist!')
    elif config_algorithm == 'SAC':
        if config_representation == 'Tabular':
            actor_dict = {0:
                               {'name': 'Dense',
                                       'params': {
                                           'units': 64,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                           1:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 32,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                           2:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 16,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                           3:
                               {'name': 'Flatten',
                                'params': {}
                                },
                           4:
                               {'name': 'Dense',
                                'params': {
                                    'units': 512,
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           5:
                               {'name': 'Dense',
                                'params': {
                                    'units': config_environment.action_space.n,
                                    'activation': 'softmax'
                                }}}
            critic_dict = {0:
                               {'name': 'Dense',
                                       'params': {
                                           'units': 64,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                           1:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 32,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                           2:
                                     {'name': 'Dense',
                                       'params': {
                                           'units': 16,
                                           'activation': 'relu',
                                           'kernel_initializer': tf.keras.initializers.HeNormal()
                                       }},
                           3:
                               {'name': 'Flatten',
                                'params': {}
                                },
                           4:
                               {'name': 'Dense',
                                'params': {
                                    'units': 512,
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           5:
                               {'name': 'Dense',
                                'params': {
                                    'units': config_environment.action_space.n,
                                    'activation': None
                                }}}
            return [actor_dict, critic_dict]
        elif config_representation == 'Graphic':
            actor_dict = {0:
                               {'name': 'Conv2D',
                                'params': {
                                    'filters': 32,
                                    'kernel_size': (8, 8),
                                    'strides': (4, 4),
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           1:
                               {'name': 'Conv2D',
                                'params': {
                                    'filters': 64,
                                    'kernel_size': (4, 4),
                                    'strides': (2, 2),
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           2:
                               {'name': 'Conv2D',
                                'params': {
                                    'filters': 64,
                                    'kernel_size': (3, 3),
                                    'strides': (1, 1),
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           3:
                               {'name': 'Flatten',
                                'params': {}
                                },
                           4:
                               {'name': 'Dense',
                                'params': {
                                    'units': 512,
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           5:
                               {'name': 'Dense',
                                'params': {
                                    'units': config_environment.action_space.n,
                                    'activation': 'softmax'
                                }}}
            critic_dict = {0:
                               {'name': 'Conv2D',
                                'params': {
                                    'filters': 32,
                                    'kernel_size': (8, 8),
                                    'strides': (4, 4),
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           1:
                               {'name': 'Conv2D',
                                'params': {
                                    'filters': 64,
                                    'kernel_size': (4, 4),
                                    'strides': (2, 2),
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           2:
                               {'name': 'Conv2D',
                                'params': {
                                    'filters': 64,
                                    'kernel_size': (3, 3),
                                    'strides': (1, 1),
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           3:
                               {'name': 'Flatten',
                                'params': {}
                                },
                           4:
                               {'name': 'Dense',
                                'params': {
                                    'units': 512,
                                    'activation': 'relu',
                                    'kernel_initializer': tf.keras.initializers.HeNormal()
                                }},
                           5:
                               {'name': 'Dense',
                                'params': {
                                    'units': config_environment.action_space.n,
                                    'activation': None
                                }}}
            return [actor_dict, critic_dict]
        else:
            raise ValueError('Representation provided does not exist!')
    else: 
        raise ValueError('Algorithm provided does not exist!')


def get_agent(config_env, config_algorithm, config_network_dicts, config_network_path, config_test_params):
    if config_algorithm == 'DDDQN':
        return DDDQNAgent(observation_space=config_env.observation_space,
                      action_space=config_env.action_space,
                      q_net_dict=config_network_dicts,
                      q_target_net_dict=config_network_dicts,
                      double_q=True,
                      dueling_q=True,
                      q_net_update=4,
                      q_target_net_update=10000,
                      discount_factor=0.99,
                      q_net_optimizer=tf.keras.optimizers.Adam,
                      q_target_net_optimizer=tf.keras.optimizers.Adam,
                      q_net_learning_rate=1e-4,
                      q_target_net_learning_rate=1e-4,
                      q_net_loss=tf.keras.losses.Huber(),
                      q_target_net_loss=tf.keras.losses.Huber(),
                      num_episodes=config_test_params['num_episodes'],
                      learning_starts=config_test_params['learning_starts'],
                      memory_size=config_test_params['memory_size'],
                      memory_alpha=config_test_params['memory_alpha'],
                      memory_beta=config_test_params['memory_beta'],
                      max_epsilon=config_test_params['max_epsilon'],
                      min_epsilon=config_test_params['min_epsilon'],
                      epsilon_a=config_test_params['epsilon_a'],
                      epsilon_b=config_test_params['epsilon_b'],
                      epsilon_c=config_test_params['epsilon_c'],
                      batch_size=config_test_params['batch_size'],
                      max_norm_grad=10,
                      tau=1,
                      checkpoint_dir=config_network_path)
    elif config_algorithm == 'SAC':
        return SACAgent(observation_space=config_env.observation_space,
                    action_space=config_env.action_space,
                    actor_net_dict=config_network_dicts[0],
                    critic_net_dict=config_network_dicts[1],
                    net_update=1,
                    discount_factor=0.99,
                    actor_net_optimizer=tf.keras.optimizers.Adam,
                    critic_net_optimizer=tf.keras.optimizers.Adam,
                    actor_net_learning_rate=3e-4,
                    critic_net_learning_rate=3e-4,
                    actor_net_loss=tf.keras.losses.Huber(),
                    critic_net_loss=tf.keras.losses.Huber(),
                    num_episodes=config_test_params['num_episodes'],
                    learning_starts=config_test_params['learning_starts'],
                    memory_size=config_test_params['memory_size'],
                    memory_alpha=config_test_params['memory_alpha'],
                    memory_beta=config_test_params['memory_beta'],
                    max_epsilon=config_test_params['max_epsilon'],
                    min_epsilon=config_test_params['min_epsilon'],
                    epsilon_a=config_test_params['epsilon_a'],
                    epsilon_b=config_test_params['epsilon_b'],
                    epsilon_c=config_test_params['epsilon_c'],
                    batch_size=config_test_params['batch_size'],
                    max_norm_grad=5,
                    tau=0.005,
                    entropy_coeff=None,
                    initial_entropy_coeff=50.,
                    checkpoint_dir=config_network_path)
    else: 
        raise ValueError('Algorithm provided does not exist!')

# %% [markdown]
# # TEST LOOP

# %%
# TEST LOOP

for config in itertools.product(*[['SAC'], ['Santorini'], ['Graphic','Tabular'], ['Random']]):
        print('Executing the following config: {}'.format(config))
        algorithm = config[0]
        environment = config[1]
        representation = config[2]
        opponent = config[3]
        agent_turn = 'Random'
        test_params = {
            'num_episodes': 200000,
            'learning_starts': 1000,
            'memory_size': 32768,
            'memory_alpha': 0.7,
            'memory_beta': 0.4,
            'max_epsilon': 1.0,
            'min_epsilon': 0.05,
            'epsilon_a': 0.06,
            'epsilon_b':0.05,
            'epsilon_c':1.5,
            'batch_size':32
        }

        if (environment in ['TicTacToe', 'ConnectFour'] and opponent in ['MonteCarlo']) or (environment in ['Santorini'] and opponent in ['MinMaxRandom']):
            print('Config {} not supported, skipping...'.format(config))
            continue

        config_name = algorithm + '_' + environment + '_' + representation + '_' + opponent + '_' + agent_turn
        data_path = 'drive/MyDrive/DOT/Test/' + config_name + '/'
        gif_path = data_path + 'GIFs/'
        network_path = data_path + 'NetworkParameters/'
        os.mkdir(data_path)
        os.mkdir(gif_path)
        os.mkdir(network_path)

        turn = get_turn(agent_turn)
        env = get_env(environment, representation, turn, opponent)
        network_dicts = get_network_dicts(algorithm, representation, env)
        agent = get_agent(env, algorithm, network_dicts, network_path, test_params)

        wizard = TurnGameTrainWizard(environment_name=environment,
                                     agent=agent,
                                     objective_score=1,
                                     running_average_length=100,
                                     evaluation_steps=200,
                                     evaluation_games=5,
                                     representation=representation,
                                     agent_turn=turn,
                                     agent_turn_test=None,
                                     opponent=opponent,
                                     data_path=data_path,
                                     gif_path=gif_path,
                                     save_agent_checkpoints=False,
                                     montecarlo_init_sim=0,
                                     montecarlo_normal_sim=0)

        wizard.train()
        wizard.agent.save()
# Out:
# Executing the following config: ('SAC', 'Santorini', 'Graphic', 'Random')
# /usr/local/lib/python3.7/dist-packages/gym/core.py:330: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# 0it [00:00, ?it/s]
# Output streaming troncato alle ultime 5000 righe.
# │ Average Game Length: 14.60                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.16                    │
# │ Running Average Game Length: 12.18             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 116802 | Learning Step: 115803      │
# │ Epsilon: 0.05 | Last Loss: -0.5925957560539246 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 16.20                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.19                    │
# │ Running Average Game Length: 12.40             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 117001 | Learning Step: 116002      │
# │ Epsilon: 0.05 | Last Loss: -0.5645153522491455 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 11.00                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.13                    │
# │ Running Average Game Length: 12.34             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 117201 | Learning Step: 116202      │
# │ Epsilon: 0.05 | Last Loss: -0.4926947355270386 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 9.00                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.07                    │
# │ Running Average Game Length: 12.14             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 117401 | Learning Step: 116402     │
# │ Epsilon: 0.05 | Last Loss: -0.674086332321167 │
# │ Test Results:                                 │
# │ Average Score: 0.40                           │
# │ Average Game Length: 13.00                    │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1    │
# │ Test Running Average:                         │
# │ Running Average Score: 0.10                   │
# │ Running Average Game Length: 12.28            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 117601 | Learning Step: 116602      │
# │ Epsilon: 0.05 | Last Loss: -0.5707745552062988 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 11.40                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.01                    │
# │ Running Average Game Length: 12.08             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 117801 | Learning Step: 116802      │
# │ Epsilon: 0.05 | Last Loss: -0.5728552937507629 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 13.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.01                    │
# │ Running Average Game Length: 12.24             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 118001 | Learning Step: 117002      │
# │ Epsilon: 0.05 | Last Loss: -0.7016376852989197 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 13.80                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.10                    │
# │ Running Average Game Length: 12.52             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 118202 | Learning Step: 117203     │
# │ Epsilon: 0.05 | Last Loss: -0.380142480134964 │
# │ Test Results:                                 │
# │ Average Score: -0.80                          │
# │ Average Game Length: 11.40                    │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3    │
# │ Test Running Average:                         │
# │ Running Average Score: 0.07                   │
# │ Running Average Game Length: 12.56            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 118401 | Learning Step: 117402      │
# │ Epsilon: 0.05 | Last Loss: -0.6472668051719666 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.10                    │
# │ Running Average Game Length: 12.36             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 118602 | Learning Step: 117603     │
# │ Epsilon: 0.05 | Last Loss: -0.659431517124176 │
# │ Test Results:                                 │
# │ Average Score: -0.20                          │
# │ Average Game Length: 13.40                    │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2    │
# │ Test Running Average:                         │
# │ Running Average Score: 0.07                   │
# │ Running Average Game Length: 12.44            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 118801 | Learning Step: 117802      │
# │ Epsilon: 0.05 | Last Loss: -0.5714195966720581 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.01                    │
# │ Running Average Game Length: 12.36             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 119001 | Learning Step: 118002      │
# │ Epsilon: 0.05 | Last Loss: -0.6216608881950378 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 15.40                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.01                    │
# │ Running Average Game Length: 12.54             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 119201 | Learning Step: 118202      │
# │ Epsilon: 0.05 | Last Loss: -0.7183735370635986 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.02                   │
# │ Running Average Game Length: 12.34             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 119401 | Learning Step: 118402      │
# │ Epsilon: 0.05 | Last Loss: -0.5967025756835938 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 12.60                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.01                    │
# │ Running Average Game Length: 12.26             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 119601 | Learning Step: 118602      │
# │ Epsilon: 0.05 | Last Loss: -0.7093377113342285 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 14.60                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.02                   │
# │ Running Average Game Length: 12.20             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 119801 | Learning Step: 118802      │
# │ Epsilon: 0.05 | Last Loss: -0.6084334850311279 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.05                   │
# │ Running Average Game Length: 12.14             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 120001 | Learning Step: 119002      │
# │ Epsilon: 0.05 | Last Loss: -0.5367417335510254 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.05                   │
# │ Running Average Game Length: 12.22             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 120201 | Learning Step: 119202      │
# │ Epsilon: 0.05 | Last Loss: -0.4849355220794678 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 11.00                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 12.14             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 120402 | Learning Step: 119403      │
# │ Epsilon: 0.05 | Last Loss: -0.5255619287490845 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 12.14             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 120601 | Learning Step: 119602      │
# │ Epsilon: 0.05 | Last Loss: -0.6947636604309082 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 9.40                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.88             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 120801 | Learning Step: 119802      │
# │ Epsilon: 0.05 | Last Loss: -0.6562092304229736 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.23                   │
# │ Running Average Game Length: 11.56             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 121001 | Learning Step: 120002      │
# │ Epsilon: 0.05 | Last Loss: -0.6166052222251892 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.00                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.20                   │
# │ Running Average Game Length: 11.56             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 121201 | Learning Step: 120202      │
# │ Epsilon: 0.05 | Last Loss: -0.6182268857955933 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 11.80                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.70             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 121401 | Learning Step: 120402      │
# │ Epsilon: 0.05 | Last Loss: -0.6015523672103882 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 12.20                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.66             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 121601 | Learning Step: 120602      │
# │ Epsilon: 0.05 | Last Loss: -0.6948345899581909 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 13.00                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 11.74             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 121801 | Learning Step: 120802      │
# │ Epsilon: 0.05 | Last Loss: -0.7802578210830688 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 15.40                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 11.82             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 122001 | Learning Step: 121002      │
# │ Epsilon: 0.05 | Last Loss: -0.5816559791564941 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 13.40                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.80             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 122201 | Learning Step: 121202      │
# │ Epsilon: 0.05 | Last Loss: -0.6632429957389832 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 15.00                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 11.98             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 122401 | Learning Step: 121402      │
# │ Epsilon: 0.05 | Last Loss: -0.6254581212997437 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 12.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 12.12             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 122601 | Learning Step: 121602      │
# │ Epsilon: 0.05 | Last Loss: -0.7335988283157349 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 11.94             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 122801 | Learning Step: 121802      │
# │ Epsilon: 0.05 | Last Loss: -0.5440351963043213 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 12.20                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.05                   │
# │ Running Average Game Length: 11.96             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 123001 | Learning Step: 122002      │
# │ Epsilon: 0.05 | Last Loss: -0.7080265283584595 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 6.60                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.52             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 123201 | Learning Step: 122202      │
# │ Epsilon: 0.05 | Last Loss: -0.5770801901817322 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 11.00                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.58             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 123401 | Learning Step: 122402      │
# │ Epsilon: 0.05 | Last Loss: -0.6154301166534424 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 18.20                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 11.86             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 123601 | Learning Step: 122602      │
# │ Epsilon: 0.05 | Last Loss: -0.6900378465652466 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.62             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 123802 | Learning Step: 122803      │
# │ Epsilon: 0.05 | Last Loss: -0.5863434076309204 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 10.20                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.60             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 124001 | Learning Step: 123002      │
# │ Epsilon: 0.05 | Last Loss: -0.7338165044784546 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.60             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 124201 | Learning Step: 123202      │
# │ Epsilon: 0.05 | Last Loss: -0.6394129991531372 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 13.00                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.05                   │
# │ Running Average Game Length: 11.70             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 124401 | Learning Step: 123402      │
# │ Epsilon: 0.05 | Last Loss: -0.6645117402076721 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.08                   │
# │ Running Average Game Length: 11.74             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 124602 | Learning Step: 123603     │
# │ Epsilon: 0.05 | Last Loss: -0.598577618598938 │
# │ Test Results:                                 │
# │ Average Score: -0.80                          │
# │ Average Game Length: 9.80                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.08                  │
# │ Running Average Game Length: 11.76            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 124801 | Learning Step: 123802      │
# │ Epsilon: 0.05 | Last Loss: -0.5333215594291687 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.80             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 125001 | Learning Step: 124002     │
# │ Epsilon: 0.05 | Last Loss: -0.658689022064209 │
# │ Test Results:                                 │
# │ Average Score: -0.80                          │
# │ Average Game Length: 8.20                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.14                  │
# │ Running Average Game Length: 11.66            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 125201 | Learning Step: 124202      │
# │ Epsilon: 0.05 | Last Loss: -0.4593920111656189 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 15.00                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.82             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 125402 | Learning Step: 124403      │
# │ Epsilon: 0.05 | Last Loss: -0.6836495399475098 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 11.00                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.76             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 125601 | Learning Step: 124602      │
# │ Epsilon: 0.05 | Last Loss: -0.6290227174758911 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 18.20                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 12.02             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 125801 | Learning Step: 124802      │
# │ Epsilon: 0.05 | Last Loss: -0.6442691087722778 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 11.40                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.82             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 126001 | Learning Step: 125002      │
# │ Epsilon: 0.05 | Last Loss: -0.7077270150184631 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.64             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 126201 | Learning Step: 125202      │
# │ Epsilon: 0.05 | Last Loss: -0.7012765407562256 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.38             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 126401 | Learning Step: 125402      │
# │ Epsilon: 0.05 | Last Loss: -0.7284260988235474 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 11.00                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.30             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 126601 | Learning Step: 125602      │
# │ Epsilon: 0.05 | Last Loss: -0.6479019522666931 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.34             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 126801 | Learning Step: 125802      │
# │ Epsilon: 0.05 | Last Loss: -0.6973949670791626 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.20                   │
# │ Running Average Game Length: 11.22             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 127001 | Learning Step: 126002      │
# │ Epsilon: 0.05 | Last Loss: -0.6083593368530273 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 11.40                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.11                   │
# │ Running Average Game Length: 11.46             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 127202 | Learning Step: 126203      │
# │ Epsilon: 0.05 | Last Loss: -0.6227492094039917 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.20                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.42             │
# └────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────┐
# │ History:                                        │
# │ Time Step: 127401 | Learning Step: 126402       │
# │ Epsilon: 0.05 | Last Loss: -0.47530126571655273 │
# │ Test Results:                                   │
# │ Average Score: 0.00                             │
# │ Average Game Length: 12.60                      │
# │ Wins: 3 | Losses: 1 | Ties: 0 | Invalid: 1      │
# │ Test Running Average:                           │
# │ Running Average Score: -0.19                    │
# │ Running Average Game Length: 11.14              │
# └─────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 127601 | Learning Step: 126602      │
# │ Epsilon: 0.05 | Last Loss: -0.5988840460777283 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 12.60                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.16                   │
# │ Running Average Game Length: 11.28             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 127801 | Learning Step: 126802     │
# │ Epsilon: 0.05 | Last Loss: -0.594277024269104 │
# │ Test Results:                                 │
# │ Average Score: 0.40                           │
# │ Average Game Length: 12.20                    │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.10                  │
# │ Running Average Game Length: 11.38            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 128001 | Learning Step: 127002      │
# │ Epsilon: 0.05 | Last Loss: -0.5750275254249573 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 8.20                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.13                   │
# │ Running Average Game Length: 11.30             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 128202 | Learning Step: 127203     │
# │ Epsilon: 0.05 | Last Loss: -0.715823769569397 │
# │ Test Results:                                 │
# │ Average Score: -0.20                          │
# │ Average Game Length: 9.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.16                  │
# │ Running Average Game Length: 11.14            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 128401 | Learning Step: 127402      │
# │ Epsilon: 0.05 | Last Loss: -0.7100050449371338 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.20                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.13                   │
# │ Running Average Game Length: 11.12             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 128601 | Learning Step: 127602      │
# │ Epsilon: 0.05 | Last Loss: -0.7404439449310303 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 16.20                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.04                   │
# │ Running Average Game Length: 11.44             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 128801 | Learning Step: 127802     │
# │ Epsilon: 0.05 | Last Loss: -0.620028018951416 │
# │ Test Results:                                 │
# │ Average Score: 0.40                           │
# │ Average Game Length: 13.40                    │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1    │
# │ Test Running Average:                         │
# │ Running Average Score: 0.02                   │
# │ Running Average Game Length: 11.58            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 129001 | Learning Step: 128002      │
# │ Epsilon: 0.05 | Last Loss: -0.5980492234230042 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 13.40                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.08                    │
# │ Running Average Game Length: 11.84             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 129201 | Learning Step: 128202      │
# │ Epsilon: 0.05 | Last Loss: -0.7588512301445007 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.02                    │
# │ Running Average Game Length: 11.58             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 129402 | Learning Step: 128403      │
# │ Epsilon: 0.05 | Last Loss: -0.6898029446601868 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.20                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: 0.05                    │
# │ Running Average Game Length: 11.54             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 129601 | Learning Step: 128602      │
# │ Epsilon: 0.05 | Last Loss: -0.6048147678375244 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 6.60                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.07                   │
# │ Running Average Game Length: 10.96             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 129801 | Learning Step: 128802      │
# │ Epsilon: 0.05 | Last Loss: -0.7692598700523376 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.40                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.10                   │
# │ Running Average Game Length: 10.96             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 130001 | Learning Step: 129002     │
# │ Epsilon: 0.05 | Last Loss: -0.508135199546814 │
# │ Test Results:                                 │
# │ Average Score: -0.20                          │
# │ Average Game Length: 12.20                    │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.10                  │
# │ Running Average Game Length: 11.08            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 130202 | Learning Step: 129203      │
# │ Epsilon: 0.05 | Last Loss: -0.5751938819885254 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.40                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.07                   │
# │ Running Average Game Length: 11.16             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 130401 | Learning Step: 129402      │
# │ Epsilon: 0.05 | Last Loss: -0.7340877056121826 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 7.40                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.16                   │
# │ Running Average Game Length: 10.98             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 130601 | Learning Step: 129602      │
# │ Epsilon: 0.05 | Last Loss: -0.6515111327171326 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 8.20                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.16                   │
# │ Running Average Game Length: 10.86             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 130801 | Learning Step: 129802      │
# │ Epsilon: 0.05 | Last Loss: -0.6726706027984619 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.16                   │
# │ Running Average Game Length: 10.96             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 131001 | Learning Step: 130002      │
# │ Epsilon: 0.05 | Last Loss: -0.7281809449195862 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 13.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.19                   │
# │ Running Average Game Length: 11.08             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────┐
# │ History:                                   │
# │ Time Step: 131201 | Learning Step: 130202  │
# │ Epsilon: 0.05 | Last Loss: -0.61279296875  │
# │ Test Results:                              │
# │ Average Score: 0.40                        │
# │ Average Game Length: 11.00                 │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1 │
# │ Test Running Average:                      │
# │ Running Average Score: -0.16               │
# │ Running Average Game Length: 11.12         │
# └────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 131401 | Learning Step: 130402      │
# │ Epsilon: 0.05 | Last Loss: -0.6226490139961243 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 15.00                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.24             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 131601 | Learning Step: 130602      │
# │ Epsilon: 0.05 | Last Loss: -0.6318495273590088 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.20             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 131801 | Learning Step: 130802      │
# │ Epsilon: 0.05 | Last Loss: -0.6138757467269897 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 12.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.20                   │
# │ Running Average Game Length: 11.22             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 132001 | Learning Step: 131002      │
# │ Epsilon: 0.05 | Last Loss: -0.6760414838790894 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 6.60                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.23                   │
# │ Running Average Game Length: 11.14             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# ...
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 195001 | Learning Step: 194002     │
# │ Epsilon: 0.05 | Last Loss: -0.685681939125061 │
# │ Test Results:                                 │
# │ Average Score: -0.80                          │
# │ Average Game Length: 12.20                    │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.17                  │
# │ Running Average Game Length: 11.80            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 195201 | Learning Step: 194202      │
# │ Epsilon: 0.05 | Last Loss: -0.7589397430419922 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.80                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.82             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 195401 | Learning Step: 194402      │
# │ Epsilon: 0.05 | Last Loss: -0.6246069669723511 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.23                   │
# │ Running Average Game Length: 11.68             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 195601 | Learning Step: 194602      │
# │ Epsilon: 0.05 | Last Loss: -0.6089780926704407 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 11.40                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.23                   │
# │ Running Average Game Length: 11.58             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 195801 | Learning Step: 194802      │
# │ Epsilon: 0.05 | Last Loss: -0.6301565766334534 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 14.20                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.20                   │
# │ Running Average Game Length: 11.82             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 196001 | Learning Step: 195002      │
# │ Epsilon: 0.05 | Last Loss: -0.6720246076583862 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 12.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.14                   │
# │ Running Average Game Length: 11.90             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 196202 | Learning Step: 195203      │
# │ Epsilon: 0.05 | Last Loss: -0.7110658884048462 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 11.00                     │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.86             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 196401 | Learning Step: 195402      │
# │ Epsilon: 0.05 | Last Loss: -0.5995972156524658 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 12.20                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.94             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 196601 | Learning Step: 195602      │
# │ Epsilon: 0.05 | Last Loss: -0.6786789298057556 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 12.02             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 196801 | Learning Step: 195802      │
# │ Epsilon: 0.05 | Last Loss: -0.6470199823379517 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.17                   │
# │ Running Average Game Length: 11.94             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 197001 | Learning Step: 196002      │
# │ Epsilon: 0.05 | Last Loss: -0.7403240203857422 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.26                   │
# │ Running Average Game Length: 11.78             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 197201 | Learning Step: 196202      │
# │ Epsilon: 0.05 | Last Loss: -0.6343191862106323 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 7.00                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.29                   │
# │ Running Average Game Length: 11.64             │
# └────────────────────────────────────────────────┘
# ┌───────────────────────────────────────────────┐
# │ History:                                      │
# │ Time Step: 197401 | Learning Step: 196402     │
# │ Epsilon: 0.05 | Last Loss: -0.800213098526001 │
# │ Test Results:                                 │
# │ Average Score: -0.20                          │
# │ Average Game Length: 12.20                    │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2    │
# │ Test Running Average:                         │
# │ Running Average Score: -0.29                  │
# │ Running Average Game Length: 11.74            │
# └───────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 197601 | Learning Step: 196602      │
# │ Epsilon: 0.05 | Last Loss: -0.7929754257202148 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 12.20                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.29                   │
# │ Running Average Game Length: 11.78             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 197801 | Learning Step: 196802      │
# │ Epsilon: 0.05 | Last Loss: -0.7098593711853027 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.29                   │
# │ Running Average Game Length: 11.68             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 198001 | Learning Step: 197002      │
# │ Epsilon: 0.05 | Last Loss: -0.5527550578117371 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 7.80                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.35                   │
# │ Running Average Game Length: 11.50             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 198201 | Learning Step: 197202      │
# │ Epsilon: 0.05 | Last Loss: -0.5548762083053589 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 13.00                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.32                   │
# │ Running Average Game Length: 11.50             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 198401 | Learning Step: 197402      │
# │ Epsilon: 0.05 | Last Loss: -0.6418041586875916 │
# │ Test Results:                                  │
# │ Average Score: 1.00                            │
# │ Average Game Length: 13.40                     │
# │ Wins: 5 | Losses: 0 | Ties: 0 | Invalid: 0     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.32                   │
# │ Running Average Game Length: 11.44             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 198601 | Learning Step: 197602      │
# │ Epsilon: 0.05 | Last Loss: -0.8006937503814697 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 11.80                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.35                   │
# │ Running Average Game Length: 11.42             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 198801 | Learning Step: 197802      │
# │ Epsilon: 0.05 | Last Loss: -0.7094736695289612 │
# │ Test Results:                                  │
# │ Average Score: -0.80                           │
# │ Average Game Length: 10.20                     │
# │ Wins: 2 | Losses: 0 | Ties: 0 | Invalid: 3     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.41                   │
# │ Running Average Game Length: 11.22             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 199001 | Learning Step: 198002      │
# │ Epsilon: 0.05 | Last Loss: -0.6846888065338135 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 11.40                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.38                   │
# │ Running Average Game Length: 11.18             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 199201 | Learning Step: 198202      │
# │ Epsilon: 0.05 | Last Loss: -0.6314566135406494 │
# │ Test Results:                                  │
# │ Average Score: 0.40                            │
# │ Average Game Length: 12.20                     │
# │ Wins: 4 | Losses: 0 | Ties: 0 | Invalid: 1     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.35                   │
# │ Running Average Game Length: 11.20             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 199401 | Learning Step: 198402      │
# │ Epsilon: 0.05 | Last Loss: -0.7843527793884277 │
# │ Test Results:                                  │
# │ Average Score: -1.40                           │
# │ Average Game Length: 6.60                      │
# │ Wins: 1 | Losses: 0 | Ties: 0 | Invalid: 4     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.38                   │
# │ Running Average Game Length: 11.04             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 199601 | Learning Step: 198602      │
# │ Epsilon: 0.05 | Last Loss: -0.7257705926895142 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 10.60                     │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.41                   │
# │ Running Average Game Length: 11.00             │
# └────────────────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │ History:                                       │
# │ Time Step: 199801 | Learning Step: 198802      │
# │ Epsilon: 0.05 | Last Loss: -0.5629487633705139 │
# │ Test Results:                                  │
# │ Average Score: -0.20                           │
# │ Average Game Length: 9.80                      │
# │ Wins: 3 | Losses: 0 | Ties: 0 | Invalid: 2     │
# │ Test Running Average:                          │
# │ Running Average Score: -0.44                   │
# │ Running Average Game Length: 10.78             │
# └────────────────────────────────────────────────┘
# Saving models and parameters...
# Executing the following config: ('SAC', 'Santorini', 'Tabular', 'Random')
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-7-2256d6a4abb7> in <module>
#      30         gif_path = data_path + 'GIFs/'
#      31         network_path = data_path + 'NetworkParameters/'
# ---> 32         os.mkdir(data_path)
#      33         os.mkdir(gif_path)
#      34         os.mkdir(network_path)
#
# FileExistsError: [Errno 17] File exists: 'drive/MyDrive/DOT/Test/SAC_Santorini_Tabular_Random_Random/'

# %% [markdown]
# # PLOTS

# %%
#DISPLAY REWARD PLOT

sns.set(rc={'figure.figsize': (16, 9)})
fig, ax = plt.subplots()
ax.set(ylim=(-2, 1))

for config in itertools.product(*[['DDDQN', 'SAC'], ['TicTacToe'], ['Graphic'], ['MinMaxRandom'],
                                      ['First','Second','Random']]):
    algorithm = config[0]
    environment = config[1]
    representation = config[2]
    opponent = config[3]
    agent_turn = config[4]
    if (environment in ['TicTacToe', 'ConnectFour'] and opponent in ['MonteCarlo']) or (environment in ['Santorini'] and opponent in ['MinMaxRandom']):
            print('Config {} not supported, skipping...'.format(config))
            continue
    config_name = algorithm + '_' + environment + '_' + representation + '_' + opponent + '_' + agent_turn
    data_path = 'drive/MyDrive/DOT/Test/' + config_name + '/scores.pkl'
    f = open(data_path, 'rb')
    results_random = pickle.load(f)
    f.close()
    data_random_reward = pd.DataFrame(np.array([(key, value[i][0]) for key, value in results_random.items() for i in
                                                range(len(value))]), columns=['episode', 'reward'])
    data_random_reward['rolling'] = data_random_reward.reward.rolling(100).mean()
    
    #ax = sns.lineplot(x='episode', y='reward', data=data_random_reward, label=config_name)
    ax = sns.lineplot(x='episode', y='reward', data=data_random_reward, label=config_name+'_rolling')

plt.show()

# %%
#DISPLAY LENGTH PLOT

sns.set(rc={'figure.figsize': (16, 9)})
fig, ax = plt.subplots()
ax.set(ylim=(42, 0))

for config in itertools.product(*[['DDDQN', 'SAC'], ['TicTacToe'], ['Tabular', 'Graphic'], ['Random', 'MinMaxRandom', 'MonteCarlo'],
                                      ['First', 'Second', 'Random']]):
    algorithm = config[0]
    environment = config[1]
    representation = config[2]
    opponent = config[3]
    agent_turn = config[4]
    if (environment in ['TicTacToe', 'ConnectFour'] and opponent in ['MonteCarlo']) or (environment in ['Santorini'] and opponent in ['MinMaxRandom']):
            print('Config {} not supported, skipping...'.format(config))
            continue
    config_name = algorithm + '_' + environment + '_' + representation + '_' + opponent + '_' + agent_turn
    data_path = 'drive/MyDrive/DOT/Test/' + config_name + '/scores.pkl'
    f = open(data_path, 'rb')
    results_random = pickle.load(f)
    f.close()
    data_random_length = pd.DataFrame(np.array([(key, value[i][1]) for key, value in results_random.items() for i in
                                                range(len(value))]), columns=['episode', 'length'])
    data_random_length['rolling'] = data_random_length.length.rolling(100).mean()
    
    #ax = sns.lineplot(x='episode', y='length', data=data_random_reward, label=config_name)
    ax = sns.lineplot(x='episode', y='length', data=data_random_length, label=config_name+'_rolling')

plt.show()
